# %% [markdown]
# <a href="https://colab.research.google.com/github/MRazin172/RM/blob/main/RM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Customers.csv')
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#        CustomerID     Age  Annual Income ($)  Spending Score (1-100)  \
# count     2000.00 2000.00            2000.00                 2000.00
# mean      1000.50   48.96          110731.82                   50.96
# std        577.49   28.43           45739.54                   27.93
# min          1.00    0.00               0.00                    0.00
# 25%        500.75   25.00           74572.00                   28.00
# 50%       1000.50   48.00          110045.00                   50.00
# 75%       1500.25   73.00          149092.75                   75.00
# max       2000.00   99.00          189974.00                  100.00
#
#        Work Experience  Family Size
# count          2000.00      2000.00
# mean              4.10         3.77
# std               3.92         1.97
# min               0.00         1.00
# 25%               1.00         2.00
# 50%               3.00         4.00
# 75%               7.00         5.00
# max              17.00         9.00

# %%
#To check missing values by variable
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
#Used to calculate the number of unique values in each column
df.nunique()
# Out:
# CustomerID                2000
# Gender                       2
# Age                        100
# Annual Income ($)         1786
# Spending Score (1-100)     101
# Profession                   9
# Work Experience             18
# Family Size                  9
# dtype: int64

# %%
df.sort_values(by="Age", ascending=False).head(10)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 1103        1104  Female   99             103706                      50
# 1524        1525  Female   99             150782                      18
# 1629        1630    Male   99             162762                      52
# 361          362    Male   99              63364                      61
# 1322        1323  Female   99             144176                      74
# 1771        1772  Female   99              84167                      46
# 1188        1189  Female   99             122548                      14
# 1401        1402    Male   99             139685                      20
# 1133        1134  Female   99              57677                      99
# 351          352    Male   99             173394                       4
#
#          Profession  Work Experience  Family Size
# 1103  Entertainment                1            2
# 1524      Executive                8            2
# ...

# %%
df.corr()
# Out:
# <ipython-input-10-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         CustomerID   Age  Annual Income ($)  \
# CustomerID                    1.00  0.07               0.33
# Age                           0.07  1.00               0.02
# Annual Income ($)             0.33  0.02               1.00
# Spending Score (1-100)        0.02 -0.04               0.02
# Work Experience               0.09 -0.01               0.09
# Family Size                   0.16  0.04               0.09
#
#                         Spending Score (1-100)  Work Experience  Family Size
# CustomerID                                0.02             0.09         0.16
# Age                                      -0.04            -0.01         0.04
# ...

# %%
sns.heatmap(df.corr(), annot=True)
plt.rcParams['figure.figsize'] = (10,8)
plt.show()
# Out:
# <ipython-input-11-c37277468853>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
df.groupby('Annual Income ($)').mean()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income ($)',
#        'Spending Score (1-100)', 'Profession', 'Work Experience',
#        'Family Size'],
#       dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize = (25,10))
# Out:
# <Axes: >

# %%
df.select_dtypes(include = 'object')
# Out:
#       Gender     Profession
# 0       Male     Healthcare
# 1       Male       Engineer
# 2     Female       Engineer
# 3     Female         Lawyer
# 4     Female  Entertainment
# ...      ...            ...
# 1995  Female         Artist
# 1996  Female         Doctor
# 1997    Male     Healthcare
# 1998    Male      Executive
# 1999    Male  Entertainment
#
# [2000 rows x 2 columns]
